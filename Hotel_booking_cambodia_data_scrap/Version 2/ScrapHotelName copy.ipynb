# %%
import pandas as pd

# %%
df = pd.read_csv("combineBookingWeb14_15.csv")
df
# Out:
#      Unnamed: 0                              Hotel    Price  \
# 0             0        Two Seasons Siem Reap Hotel  304,849
# 1             1        Prince d'Angkor Hotel & Spa  346,511
# 2             2            Royal Crown Hotel & Spa  183,833
# 3             3         Five Rose Siem Reap Hostel   60,305
# 4             4                   Chamraoen’s Home   64,844
# ..          ...                                ...      ...
# 445          25  Le Jardin d'Angkor Hotel & Resort  200,612
# 446          26             Golden Temple Boutique  762,324
# 447          27                   The Bliss Angkor  354,049
# 448          28                  Mane Hariharalaya  957,019
# 449          29                Starry Angkor Hotel  142,171
#
#                                               Location  \
# 0                       Siem Reap | 0.5 km from centre
# 1    Old French Quarter, Siem Reap | 150 m from centre
# 2                       Siem Reap | 0.8 km from centre
# ...

# %%
test = df.drop(["Unnamed: 0", "Price", "Location", "Url"], axis = 1)
test
# Out:
#                                  Hotel
# 0          Two Seasons Siem Reap Hotel
# 1          Prince d'Angkor Hotel & Spa
# 2              Royal Crown Hotel & Spa
# 3           Five Rose Siem Reap Hostel
# 4                     Chamraoen’s Home
# ..                                 ...
# 445  Le Jardin d'Angkor Hotel & Resort
# 446             Golden Temple Boutique
# 447                   The Bliss Angkor
# 448                  Mane Hariharalaya
# 449                Starry Angkor Hotel
#
# [450 rows x 1 columns]

# %%
df1 = pd.read_csv("combineBookingWeb3_4.csv")
df1
# Out:
#      Unnamed: 0                                 Hotel    Price  \
# 0             0  Garden Village Guesthouse & Pool Bar   36,475
# 1             1          The Twizt - Lifestyle Hostel   64,763
# 2             2            Five Rose Siem Reap Hostel   40,122
# 3             3           Two Seasons Siem Reap Hotel  275,871
# 4             4                     Onederz Siem Reap  118,746
# ..          ...                                   ...      ...
# 505          25                       DV Angkor Villa   62,007
# 506          26                  Golden Orchid Angkor  114,004
# 507          27                Apsara Residence Hotel  242,760
# 508          28                           Kesya Hotel  151,573
# 509          29           Royal Crown Hotel Siem Reap  155,423
#
#                                               Location  \
# 0           Sok San Road, Siem Reap | 1 km from centre
# 1    Old French Quarter, Siem Reap | 200 m from centre
# ...

# %%
test1 = df1.drop(["Unnamed: 0", "Price", "Location", "Url"], axis = 1)
test1
# Out:
#                                     Hotel
# 0    Garden Village Guesthouse & Pool Bar
# 1            The Twizt - Lifestyle Hostel
# 2              Five Rose Siem Reap Hostel
# 3             Two Seasons Siem Reap Hotel
# 4                       Onederz Siem Reap
# ..                                    ...
# 505                       DV Angkor Villa
# 506                  Golden Orchid Angkor
# 507                Apsara Residence Hotel
# 508                           Kesya Hotel
# 509           Royal Crown Hotel Siem Reap
#
# [510 rows x 1 columns]

# %%
test = test.append(test1)
test = test.drop_duplicates()
test
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15296\3317194540.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test.append(test1)
#                            Hotel
# 0    Two Seasons Siem Reap Hotel
# 1    Prince d'Angkor Hotel & Spa
# 2        Royal Crown Hotel & Spa
# 3     Five Rose Siem Reap Hostel
# 4               Chamraoen’s Home
# ..                           ...
# 411               Viroth's Villa
# 412                  Baahu Villa
# 424         Residence Wat Damnak
# 502           Aniza Angkor Villa
# 509  Royal Crown Hotel Siem Reap
#
# [412 rows x 1 columns]

# %%
fileName = test.to_csv(f'AllHotelName.csv')
