# %% [markdown]
# **<h1 style='text-align:center'>Hotel Recommendation</h1>**
# **<h5 style='text-align:center'>By Group 4</h5>**
#
# > ### **Members**
# > #### 1. LIM KIMHOUNG
# > #### 2. LUN TOLA
# > #### 3. LONG CHANLEAP
# > #### 4. RUN SAVIN
# > #### 5. LAB THAVARITH

# %%
import os
import glob
import pandas as pd
os.chdir("C:/Users/Acer/Downloads/I3/Project/DS_Project/Booking.com/hotel_Info")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combineHotelInfo.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combineHotelInfo.csv")
df
# Out:
#        Unnamed: 0                         Name  \
# 0               0  DEN HOTEL TOTONOU SIEM REAP
# 1               1  DEN HOTEL TOTONOU SIEM REAP
# 2               2  DEN HOTEL TOTONOU SIEM REAP
# 3               3  DEN HOTEL TOTONOU SIEM REAP
# 4               4  DEN HOTEL TOTONOU SIEM REAP
# ...           ...                          ...
# 55254           2        Jaya House River Park
# 55255           0        Jaya House River Park
# 55256           1        Jaya House River Park
# 55257           2        Jaya House River Park
# 55258           3        Jaya House River Park
#
#                                                   Adress  Rating  \
# 0      497 Taphul Street, Krong Siem Reap, Siem Reap,...     9.0
# 1      497 Taphul Street, Krong Siem Reap, Siem Reap,...     9.0
# 2      497 Taphul Street, Krong Siem Reap, Siem Reap,...     9.0
# 3      497 Taphul Street, Krong Siem Reap, Siem Reap,...     9.0
# 4      497 Taphul Street, Krong Siem Reap, Siem Reap,...     9.0
# ...

# %%
os.chdir("C:/Users/Acer/Downloads/I3/Project/DS_Project/Booking.com/Facilities")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combineHotelFacilities.csv", index=False, encoding='utf-8-sig')

# %%
df1 = pd.read_csv("combineHotelFacilities.csv")
df1
# Out:
#      Unnamed: 0                         Name                      Facilities
# 0             0  DEN HOTEL TOTONOU SIEM REAP          Outdoor swimming pool
# 1             1  DEN HOTEL TOTONOU SIEM REAP                Airport shuttle
# 2             2  DEN HOTEL TOTONOU SIEM REAP              Non-smoking rooms
# 3             3  DEN HOTEL TOTONOU SIEM REAP                   Free parking
# 4             4  DEN HOTEL TOTONOU SIEM REAP                      Free WiFi
# ..          ...                          ...                             ...
# 953          15        Jaya House River Park                   Free parking
# 954          16        Jaya House River Park                     Restaurant
# 955          17        Jaya House River Park  Tea/coffee maker in all rooms
# 956          18        Jaya House River Park                            Bar
# 957          19        Jaya House River Park           Exceptional breakfast
#
# [958 rows x 3 columns]
