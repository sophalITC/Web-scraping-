# %% [markdown]
# <h1><p style="text-align: center;">Motorcycals Analysis </p><h1>

# %% [markdown]
# <span style="color:pink">CHHON CHAINA         E20200934</span>
# <span style="color:pink">KOYTHOL AMRINT       E20201757</span>
# <span style="color:pink">KHENG DALISH         E20200909</span>
# <span style="color:pink">HON RATANA           E20201053</span>
# <span style="color:pink">HOK RATANAK          E20201106</span>

# %% [markdown]
# ! pip install requests
# ! pip install html5lib
# ! pip install bs4

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup 
import pandas as pd
from urllib import request
from urllib.request import Request, urlopen
from csv import writer
import requests

# %%
url="https://www.khmer24.com/km/motorcycles/honda.html"
r=requests.get(url)

# %% [markdown]
# #### 1.HONDA

# %%
import requests


request = Request(url, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage = urlopen(request).read()

soup = BeautifulSoup(webpage, 'html.parser')
soup.prettify()

Data = soup.findAll('div', class_ = 'item-detail')

# %%
soup=BeautifulSoup(webpage,'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ Honda ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ Honda, ម៉ូតូ Honda សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ Honda ថ្មី, ម៉ូតូ Honda ដែលបានប្រើ, ម៉ូតូ Honda មួយ\u200bទឹក, ម៉ូតូ Honda សម្រាប់លក់, ម៉ូតូ Honda តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ Honda, ម៉ូតូ Honda ទាំងអស់" name="keywords"/>\n   <meta content="ទិញ ឬល
# ...

# %%
Data=soup.findAll('div' ,class_='item-detail')

# %%
Data[0]
# Out:
# <div class="item-detail">
# <h2 class="item-title truncate truncate-2">"ធូដេ&amp;ជីអូណូ" កាត់ដុំនិងរាយ</h2>
# <p class="description truncate truncate-2">GIORNO AF70 និង AF77 និង ធូដេបេន&amp;បុិច ម៉ូដែលឆ្នាំ (2011-2019) កាត់ដុំនិងរាយ​ អាចអញ្ចេីញមកជាវនៅហាងទឹកល្អក់3</p> <ul class="list-unstyled summary">
# <li>ភ្នំពេញ</li>
# <li><time datetime="2023-03-29 08:26:02">13 ម៉ោងមុន</time></li>
# <li>87 hits</li> </ul>
# <p class="item-prices m-0 text-red"><span class="price">$430</span></p>
# ...

# %%
Data[0].find('h2', {'class':'item-title'}).get_text()
# Out:
# '"ធូដេ&ជីអូណូ" កាត់ដុំនិងរាយ'

# %%
Data[0].find('p',{'class':'description truncate truncate-2'}).get_text()
# Out:
# 'GIORNO AF70 និង AF77 និង ធូដេបេន&បុិច ម៉ូដែលឆ្នាំ (2011-2019) កាត់ដុំនិងរាយ\u200b អាចអញ្ចេីញមកជាវនៅហាងទឹកល្អក់3'

# %%
Data[0].find('p',{'class' :'item-prices m-0 text-red'}).find('i')

# %%
Data[0].find('span' ,{'class':'price'}).get_text()
# Out:
# '$430'

# %%
Data[0].find('ul',{'class':'list-unstyled summary'}).get_text()
Data[0].find('li').get_text()
# Out:
# 'ភ្នំពេញ'

# %%
Data[0].find('time').get_text()
# Out:
# '13 ម៉ោងមុន'

# %%
Data = soup.findAll('article')

# %%
Data[0].find('div',{'class':'item-image'})
# Out:
# <div class="item-image">
# <img alt="&amp;quot;ធូដេ&amp;amp;ជីអូណូ&amp;quot; កាត់ដុំនិងរាយ" class="img-cover lazy" data-src="https://images.khmer24.co/23-03-17/s--quot-amp-quot--32055167903687078231443-b.jpg" src="https://www.khmer24.com//images/image-placeholder-256.png">
# <span class="shipping-tag"><span class="icon icon-truck"></span> Free Delivery</span> </img></div>

# %%
url="https://www.khmer24.com/km/motorcycles/honda.html"

request = Request(url, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'} )
webpage = urlopen(request).read()
soup = BeautifulSoup(webpage, 'html.parser')
soup.prettify()

with open('HONDAMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,155):
    x = 50*i
    url="https://www.khmer24.com/km/motorcycles/honda.html"

    HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
    webpage = urlopen(request).read()
    soup = BeautifulSoup(webpage, 'html.parser')
    soup.prettify()
    
    with open('HONDA.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 155): 
    url="https://www.khmer24.com/km/motorcycles/honda.html"
    request = Request(url, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'} )
    webpage = urlopen(request).read()
    soup = BeautifulSoup(webpage, 'html.parser')
    
    Data2 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data2:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
import pandas as pd

HONDA = pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
HONDA
# Out:
#                                        Title  \
# 0                "ធូដេ&ជីអូណូ" កាត់ដុំនិងរាយ
# 1                   Honda Rebel 250 From USA
# 2     Honda Scoopy 110cc 2020 ម៉ូតូក្រុមហ៊ុន
# 3                        Honda CT 125cc 2020
# 4                        Honda CT 125cc 2020
# ...                                      ...
# 7745                      CBR021.នៅស្អាត់99%
# 7746                      ហាងលក់ម៉ូតូ ហេងឡាយ
# 7747                                PCX 2018
# 7748                    អាសង់2016 ស្អាតសាណុំ
# 7749                          ម៉ូតូអាសង់2013
#
#                                             Description   Price Location  \
# 0     GIORNO AF70 និង AF77 និង ធូដេបេន&បុិច ម៉ូដែលឆ្...    $430  ភ្នំពេញ
# 1     Honda Rebel 250. Very good condition like new ...  $3,500  ភ្នំពេញ
# 2     ✅Honda Scoopy 2018 2019 2020\n✅ម៉ូតូមានក្រដាសព...  $1,850  ភ្នំពេញ
# 3     ✅Honda CT 125cc 2020 ម៉ូតូក្រដាសពន្ធមានគ្រឿងលេ...  $3,050  ភ្នំពេញ
# ...

# %% [markdown]
# ### 2. YAMAHAL

# %%
html="https://www.khmer24.com/km/motorcycles/yamaha.html"
r=requests.get(html)

# %%
import requests


request = Request(html, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage1 = urlopen(request).read()

soup = BeautifulSoup(webpage1, 'html.parser')
soup.prettify()

kawasaki = soup.findAll('div', class_ = 'item-detail')

# %%
soup=BeautifulSoup(webpage1,'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ Yamaha ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ Yamaha, ម៉ូតូ Yamaha សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ Yamaha ថ្មី, ម៉ូតូ Yamaha ដែលបានប្រើ, ម៉ូតូ Yamaha មួយ\u200bទឹក, ម៉ូតូ Yamaha សម្រាប់លក់, ម៉ូតូ Yamaha តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ Yamaha, ម៉ូតូ Yamaha ទាំងអស់" name="keywords"/>\n   <meta conte
# ...

# %%
yamahal=soup.findAll('div' ,class_='item-detail')

# %%
yamahal[0]
# Out:
# <div class="item-detail">
# <h2 class="item-title truncate truncate-2">Yamaha Qbix 2020 2021 Smartkey</h2>
# <p class="description truncate truncate-2">Yamaha Qbix 2020 2021 Smartkey ម៉ូតូស្អាតក្រដាសពន្ធនឹងស្លាកលេខបងបងស្រលាញ់អាចទាក់ទងមកបាន
# ……015 23 8888….</p> <ul class="list-unstyled summary">
# <li>ភ្នំពេញ</li>
# <li><time datetime="2023-03-29 22:13:48">8 នាទីមុន</time></li>
# <li>4 hits</li> </ul>
# <p class="item-prices m-0 text-red"><span class="price">$1,850</span></p>
# </div>

# %%
yamahal[0].find('h2', {'class':'item-title truncate truncate-2'}).get_text()
# Out:
# 'Yamaha Qbix 2020 2021 Smartkey'

# %%
yamahal[0].find('p',{'class':'description truncate truncate-2'}).get_text()
# Out:
# 'Yamaha Qbix 2020 2021 Smartkey ម៉ូតូស្អាតក្រដាសពន្ធនឹងស្លាកលេខបងបងស្រលាញ់អាចទាក់ទងមកបាន\n……015 23 8888….'

# %%
yamahal[0].find('p',{'class' :'item-prices m-0 text-red'}).find('i')

# %%
yamahal[0].find('span' ,{'class':'price'}).get_text()
# Out:
# '$1,850'

# %%
yamahal[0].find('ul',{'class':'list-unstyled summary'}).get_text()
yamahal[0].find('li').get_text()
# Out:
# 'ភ្នំពេញ'

# %%
yamahal[0].find('time').get_text()
# Out:
# '8 នាទីមុន'

# %%
yamahal= soup.findAll('article')

# %%
yamahal[0].find('div',{'class':'item-image'})
# Out:
# <div class="item-image">
# <img alt="Yamaha Qbix 2020 2021 Smartkey" class="img-cover lazy" data-src="https://images.khmer24.co/23-03-29/s-yamaha-qbix-2020-2021-smartkey-85335168010282536244889-b.jpg" src="https://www.khmer24.com//images/image-placeholder-256.png">
# </img></div>

# %%
html="https://www.khmer24.com/km/motorcycles/yamaha.html"
request = Request(html, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'} )
webpage = urlopen(request).read()
soup = BeautifulSoup(webpage, 'html.parser')
soup.prettify()

with open('YAMAHALMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,155):
    x = 50*i
    
    
    with open('YAMAHAL.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 155): # It's 155 page for scraping
   
    
    Data3 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data3:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
YAMAHAL = pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
YAMAHAL
# Out:
#                                                   Title  \
# 0                        Yamaha Qbix 2020 2021 Smartkey
# 1     ចង់លក់ MT 021 តំលៃ  ជិះផ្ទាល់ខ្លួន បិទស្កត់ទាំ...
# 2                               Yamaha QBIX 2020កាតគ្រី
# 3     yamaha r15 v3មានពន្ធលក់បងបងប្រញាប់លុយខ្លាំង096...
# 4                              Yamaha Filano 125cc 2021
# ...                                                 ...
# 7745           Yamaha FZ 150cc year 2016 មានពន្ធកាតគ្រី
# 7746                                 Yamaha Aeroxx 2019
# 7747                             លក់បន្ទាន់GranD FiLaNo
# 7748                                               NMAX
# 7749  I will buy a package mount from Yamaha grand f...
#
#                                             Description   Price Location  \
# 0     Yamaha Qbix 2020 2021 Smartkey ម៉ូតូស្អាតក្រដា...  $1,850  ភ្នំពេញ
# 1     ចង់លក់ MT 021 តំលៃ 2080$ ជិះផ្ទាល់ខ្លួន បិទស្ក...  $2,080  ភ្នំពេញ
# ...

# %% [markdown]
# ### 3.KAWASAKI

# %%
html2 = "https://www.khmer24.com/en/motorcycles/kawasaki.html"  
r = requests.get(html2)
r
# Out:
# <Response [403]>

# %%
html2="https://www.khmer24.com/en/motorcycles/kawasaki.html" 
request = Request(html2, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage2 = urlopen(request).read()

soup = BeautifulSoup(webpage2, 'html.parser')
soup.prettify()

kawasaki = soup.findAll('div',class_="item-detail")

# %%
soup=BeautifulSoup(webpage2,'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    New and Used Kawasaki Motorcycles For Sale in Cambodia - Khmer24.com\n   </title>\n   <meta content="Kawasaki Motorcycles, Kawasaki Motorcycles for sale in Cambodia, New Kawasaki Motorcycles, Used Kawasaki Motorcycles, Second Hand Kawasaki Motorcycles, Kawasaki Motorcycles for sale, Kawasaki Motorcycles cheep price, Kawasaki Motorcycles price, all Ka
# ...

# %%
kawasaki[0]
# Out:
# <div class="item-detail">
# <h2 class="item-title truncate truncate-2">Kawasaki Z1000R 2018 edition</h2>
# <p class="description truncate truncate-2">📸  Kawasaki Z1000R Edition
# Power : 1000CC          📸  New : 95 %
#       Year : 2018 \u</p> <ul class="list-unstyled summary">
# <li>Phnom Penh</li>
# <li><time datetime="2023-03-29 21:33:04">50 minutes ago</time></li>
# <li>14 hits</li> </ul>
# <p class="item-prices m-0 text-red"><span class="price">$10,500</span></p>
# </div>

# %%
kawasaki[0].find('h2', {'class':'item-title truncate truncate-2'}).get_text()
# Out:
# 'Kawasaki Z1000R 2018 edition'

# %%
kawasaki[0].find('p',{'class':'description truncate truncate-2'}).get_text()
# Out:
# '📸  Kawasaki Z1000R Edition  \nPower : 1000CC          📸  New : 95 % \n      Year : 2018 \\u'

# %%
kawasaki[0].find('p',{'class' :'item-prices m-0 text-red'}).find('i')

# %%
kawasaki[0].find('span' ,{'class':'price'}).get_text()
# Out:
# '$10,500'

# %%
kawasaki[0].find('ul',{'class':'list-unstyled summary'}).get_text()
kawasaki[0].find('li').get_text()
# Out:
# 'Phnom Penh'

# %%
kawasaki[0].find('time').get_text()
# Out:
# '50 minutes ago'

# %%
kawasaki= soup.findAll('article')

# %%
kawasaki[0].find('div',{'class':'item-image'})
# Out:
# <div class="item-image">
# <img alt="Kawasaki Z1000R 2018 edition" class="img-cover lazy" data-src="https://images.khmer24.co/23-03-29/s-kawasaki-z1000r-2018-edition-655008168010038147948380-g.jpg" src="https://www.khmer24.com//images/image-placeholder-256.png">
# </img></div>

# %%
html2="https://www.khmer24.com/en/motorcycles/kawasaki.html" 



with open('KAWASAKIMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,155):
    x = 50*i
    html2="https://www.khmer24.com/en/motorcycles/kawasaki.html" 

    
    
    with open('KAWASAKI.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 159): 
   
    
    Data4 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data4:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
kAWASAKI = pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
kAWASAKI
# Out:
#                                          Title  \
# 0                 Kawasaki Z1000R 2018 edition
# 1                 Kawasaki Z1000R 2018 edition
# 2                                ចង់លក់Z.250cc
# 3                            វ៉ៃដូរ Auto ឬ លក់
# 4                              Kawasaki Z250cc
# ...                                        ...
# 7945                                ER6n 650cc
# 7946                             Kawasaki w650
# 7947               ចង់លក់ Kawasaki Ninja 250cc
# 7948  Kawasaki ninja 300rr 2012 រំលស់សុទ្ធ100%
# 7949      Kawasaki z1000rr 2008 រំលស់សុទ្ធ100%
#
#                                             Description    Price  \
# 0     📸  Kawasaki Z1000R Edition  \nPower : 1000CC  ...  $10,500
# 1     📸  Kawasaki Z1000R Edition  \nPower : 1000CC  ...  $10,500
# 2                       Z.250ccលក់ប្រញាប់ម៉ូតូស្អាត់បងៗ   $1,800
# 3     វ៉ៃដូរ ជាមួយ Auto\n\nម៉ាស៊ីនតាន់, ស្ងាត់, ធន់ត...     $490
# 4                                          Good machine   $1,850
# ...

# %% [markdown]
# ### 4.SUZUKI

# %%
html3="https://www.khmer24.com/km/motorcycles/suzuki.html"
r4=requests.get(html3)

# %%
html3= "https://www.khmer24.com/km/motorcycles/suzuki.html"
request = Request(html3, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage3 = urlopen(request).read()

soup = BeautifulSoup(webpage3, 'html.parser')
soup.prettify()

kawasaki = soup.findAll('div',class_="item-detail")

# %%
html3="https://www.khmer24.com/km/motorcycles/suzuki.html"



with open('SUZUKIMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,155):
    x = 50*i
    
    html3="https://www.khmer24.com/km/motorcycles/suzuki.html"
    
    
    with open('SUZUKI.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 160): 
   
    
    Data4 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data4:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
SUZAKI = pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
SUZAKI
# Out:
#                                                   Title  \
# 0                                                   Nex
# 1                               Suzuki birdie 50cc 2012
# 2     លក់កាប់សាច់60$បញ្ចាក់វាខូចកន្លែងជើងចាប់មាសុីស្...
# 3                       Suzuki Smash V 2016(ប្រញាប់លុយ)
# 4     មានលក់មូ៉តូស្អាតសានុំហ្សុីន95%🛍🎁ឆាតរឺខលសួរបានប...
# ...                                                 ...
# 7995                                  viva 2012 on sale
# 7996                 Nex023 នៅស្អាត99% តំលៃធូជាងទីផ្សារ
# 7997  Suzuki Viva 014 Zin ម៉ូតូនៅស្អាតណាស់ មានពន្ធកា...
# 7998                     Suzuki let’s 2021សានុំខ្ចីណាស់
# 7999               Suzuki smashV 2013 ម៉ាស៊ីនមិនទាន់ដោះ
#
#                                             Description   Price  Location  \
# 0                                       តម្លៃអាចចរចាបាន    $980   ភ្នំពេញ
# 1                           ម៉ូតូស៊ីនសាណុំ កម្រមានស្អាត    $550   ភ្នំពេញ
# ...

# %% [markdown]
# ### 5.kTM

# %%
html4= "https://www.khmer24.com/km/motorcycles/ktm.html"
request = Request(html4, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage4 = urlopen(request).read()

soup = BeautifulSoup(webpage4, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ KTM ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ KTM, ម៉ូតូ KTM សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ KTM ថ្មី, ម៉ូតូ KTM ដែលបានប្រើ, ម៉ូតូ KTM មួយ\u200bទឹក, ម៉ូតូ KTM សម្រាប់លក់, ម៉ូតូ KTM តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ KTM, ម៉ូតូ KTM ទាំងអស់" name="keywords"/>\n   <meta content="ទិញ ឬលក់ ម៉ូតូ KTM ថ្មី ម៉
# ...

# %%
html4= "https://www.khmer24.com/km/motorcycles/ktm.html"



with open('kTMMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,155):
    x = 50*i
    
    html4= "https://www.khmer24.com/km/motorcycles/ktm.html"
    
    
    with open('KTM.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 161): 
   
    
    Data4 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data4:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
KTM = pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
KTM
# Out:
#                                                   Title  \
# 0            ម៉ូតូត្រៃសំរាប់លក់​ KTM sixdays 350cc 2016
# 1                                   RC016.ស្អាត់បងៗលឿនៗ
# 2                                    ហាងលក់ម៉ូតូ ហេងឡាយ
# 3                                  ចង់លក់​KTM duke 2017
# 4                                         KTM 017.250cc
# ...                                                 ...
# 8045                             KTM exc-f 2019 នៅស្អាត
# 8046                                           Duke2014
# 8047  តម្លៃចរចារ ម៉ូតូជិះផ្ទាល់ខ្លួន ប្រព័ន្ធផ្សេងដំ...
# 8048                                         KTM RC 200
# 8049                                    ម៉ូតូលក់បន្ទាន់
#
#                                             Description   Price Location  \
# 0     ម៉ូតូនៅស្អាត​ មា​នពន្ធពេញឆ្នាំ​ មានសុីមុាំងFMF...  $5,890  ភ្នំពេញ
# 1                        ចង់លក់RC016.ម៉ូតូស្អាត់ធានាអោយ  $1,380  ភ្នំពេញ
# ...

# %% [markdown]
# ###  6.DUCATI

# %%
html5= "https://www.khmer24.com/km/motorcycles/ducati.html"
request = Request(html5, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage5 = urlopen(request).read()

soup = BeautifulSoup(webpage5, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ Ducati ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ Ducati, ម៉ូតូ Ducati សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ Ducati ថ្មី, ម៉ូតូ Ducati ដែលបានប្រើ, ម៉ូតូ Ducati មួយ\u200bទឹក, ម៉ូតូ Ducati សម្រាប់លក់, ម៉ូតូ Ducati តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ Ducati, ម៉ូតូ Ducati ទាំងអស់" name="keywords"/>\n   <meta conte
# ...

# %%
html5= "https://www.khmer24.com/km/motorcycles/ducati.html"



with open('DUCATIMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,190):
    x = 50*i
    
    html4= "https://www.khmer24.com/km/motorcycles/ktm.html"
    
    
    with open('DUCATI.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 161): 
   
    
    Data4 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data4:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
DUCATI = pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
DUCATI
# Out:
#                                          Title  \
# 0           Ducati Monster 821 2018 from Japan
# 1           Ducati Monster 821 2018 from Japan
# 2                                 លក់ចោលមានកាត
# 3              Ducati Monster 821 ABS Year2014
# 4                   Ducati 2012 រំលស់សុទ្ធ100%
# ...                                        ...
# 6274         Ducati Hypermotard 796cc For Sale
# 6275           មូតូម៉ាក Ducati ខូចបេន សេរី1999
# 6276  Ducati Panigale V4 S 2019 Japan For Sale
# 6277           Ducatiម៉ាសុីនតាន់ធានាមិនទាល់ដោះ
# 6278                                Ducati 959
#
#                                             Description      Price  Location  \
# 0     ✈︎ #81A, St. 608 ពីស្តុបត្រឡោកបែក ទៅស្តុបរង្វង...     $4,500   ភ្នំពេញ
# 1     ✈︎➜➜➜ចូលមើលម៉ូដែលផ្សេងទៀត https://t.me/imotokh...     $4,500   ភ្នំពេញ
# 2                                   នៅ ស្អាត90 66902493     $3,300   ភ្នំពេញ
# 3     Hi all buyers in khmer 24 I want to sale Ducat...  $5,450.00   ភ្នំពេញ
# ...

# %% [markdown]
# ### 7.BAJAJ

# %%
html6="https://www.khmer24.com/km/motorcycles/bajaj.html"
request = Request(html6, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage6 = urlopen(request).read()

soup = BeautifulSoup(webpage6, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ Bajaj ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ Bajaj, ម៉ូតូ Bajaj សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ Bajaj ថ្មី, ម៉ូតូ Bajaj ដែលបានប្រើ, ម៉ូតូ Bajaj មួយ\u200bទឹក, ម៉ូតូ Bajaj សម្រាប់លក់, ម៉ូតូ Bajaj តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ Bajaj, ម៉ូតូ Bajaj ទាំងអស់" name="keywords"/>\n   <meta content="ទិញ ឬល
# ...

# %%
html6="https://www.khmer24.com/km/motorcycles/bajaj.html"



with open('BAJAJMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,190):
    x = 50*i
    html6="https://www.khmer24.com/km/motorcycles/bajaj.html"
    
    
    
    with open('BAJAJ.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 162): 
   
    
    Data4 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data4:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
BAJAJ = pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
BAJAJ
# Out:
#                                             Title  \
# 0                                         លក់ ចោល
# 1                                      Pulsar 200
# 2                                      Pulsar 200
# 3                             ម៉ូត៉ លក់មានកាតគ្រី
# 4                          ប្លូសា 2016 មានកាតគ្រី
# ...                                           ...
# 4855                                Pulsar RS 200
# 4856  បុកស័រម៉ូតូឥណ្ឌា ម៉ាស៊ីនបាចា លក់តម្លៃធូថ្កៃ
# 4857                                Pulsar NS 200
# 4858           Pulsa 015 មានកាតគ្រី​ វ៉ៃដូរក៏បាន​
# 4859                           ម៉ូតូលក់ប្រញាប់លុយ
#
#                                             Description   Price     Location  \
# 0                                            0966902493    $200      ភ្នំពេញ
# 1                                          Good machine    $580      ភ្នំពេញ
# 2                                          Good machine  $1,080      ភ្នំពេញ
# ...

# %% [markdown]
# ### 8.KR

# %%
html7="https://www.khmer24.com/km/motorcycles/kr-motor.html"
request = Request(html7, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage7 = urlopen(request).read()

soup = BeautifulSoup(webpage7, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ KR Motor ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ KR Motor, ម៉ូតូ KR Motor សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ KR Motor ថ្មី, ម៉ូតូ KR Motor ដែលបានប្រើ, ម៉ូតូ KR Motor មួយ\u200bទឹក, ម៉ូតូ KR Motor សម្រាប់លក់, ម៉ូតូ KR Motor តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ KR Motor, ម៉ូតូ KR Motor ទាំងអស់" name="keyword
# ...

# %%
html7="https://www.khmer24.com/km/motorcycles/kr-motor.html"



with open('KRMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,190):
    x = 45*i
    html7="https://www.khmer24.com/km/motorcycles/kr-motor.html"
    
    
    with open('KR.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 165): 
   
    
    Data5 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data5:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
KR= pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
KR
# Out:
#                                                  Title  \
# 0                                KR Moto លក់តម្លៃ 900$
# 1    ម៉ូតូលក់មានពន្ធ​មានគ្រប់ទាំងអស់កំលាំង250cc ម៉ា...
# 2                                             KR 250cc
# 3    KR 2016 250 ជិះស្រួល លឿន សម្លេងល្អ ធានាមាស៊ីនខ...
# 4                                KR Moto លក់តម្លៃ 900$
# ..                                                 ...
# 655  KR 2016 250 ជិះស្រួល លឿន សម្លេងល្អ ធានាមាស៊ីនខ...
# 656                              KR Moto លក់តម្លៃ 900$
# 657  ម៉ូតូលក់មានពន្ធ​មានគ្រប់ទាំងអស់កំលាំង250cc ម៉ា...
# 658                                           KR 250cc
# 659  KR 2016 250 ជិះស្រួល លឿន សម្លេងល្អ ធានាមាស៊ីនខ...
#
#                                            Description   Price Location  \
# 0                                           តម្លៃចរចារ    $900  ភ្នំពេញ
# 1    ម៉ូតូនៅស្អាត90%មានពន្ធត្រឹមត្រូវ​មានកាត​ 250cc...    $700  ភ្នំពេញ
# 2    ម៉ូតូមិនសូវជិះទេទុកតែជិះទៅខេត្តម៉ូតូមិនដែលបុកទ...  $1,400  ភ្នំពេញ
# ...

# %% [markdown]
# ### 9.GPX

# %%
html8="https://www.khmer24.com/km/motorcycles/gpx.html"
request = Request(html8, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage8 = urlopen(request).read()

soup = BeautifulSoup(webpage8, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ GPX ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ GPX, ម៉ូតូ GPX សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ GPX ថ្មី, ម៉ូតូ GPX ដែលបានប្រើ, ម៉ូតូ GPX មួយ\u200bទឹក, ម៉ូតូ GPX សម្រាប់លក់, ម៉ូតូ GPX តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ GPX, ម៉ូតូ GPX ទាំងអស់" name="keywords"/>\n   <meta content="ទិញ ឬលក់ ម៉ូតូ GPX ថ្មី ម៉
# ...

# %%
html8="https://www.khmer24.com/km/motorcycles/gpx.html"


with open('gpxMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,190):
    x = 45*i
    html8="https://www.khmer24.com/km/motorcycles/gpx.html"
    
    
    with open('GPX.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 165): 
   
    
    Data7 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data7:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
GPX= pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
GPX
# Out:
#                                         Title  \
# 0                               GPX PopZ 2019
# 1     GPX Rock 110 021 មួយទឹកស្លាកលេខ នៅស្អាត
# 2                                    GPX popz
# 3                                     មូតូលក់
# 4                                     មូតូលក់
# ...                                       ...
# 8245                                    ចងលក់
# 8246            ចង់លក់ម៉ូតូមួយគ្រឿងមាក់GPX150
# 8247                     លក់ GPX legend 200CC
# 8248                           កំពង់តែដុនដាប😅
# 8249           GPX Legend 200cc (black color)
#
#                                             Description    Price   Location  \
# 0     GPX PopZ 2019 for sale\n•ពណ៌ខៀវ\n•ស្លាកលេខភ្នំ...   $1,050    ភ្នំពេញ
# 1     GPX Rock 110 021 មួយទឹកស្លាកលេខ នៅស្អាត\r\nតម្...  $900.00    ភ្នំពេញ
# 2                                          Good machine   $1,150    ភ្នំពេញ
# 3                                      មូតូស្អាតមានពន្ន     $850    ភ្នំពេញ
# ...

# %% [markdown]
# ### 10.KEEWEY

# %%
html9="https://www.khmer24.com/km/motorcycles/keewey.html"
request9 = Request(html9, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage9 = urlopen(request9).read()

soup = BeautifulSoup(webpage9, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ Keewey ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ Keewey, ម៉ូតូ Keewey សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ Keewey ថ្មី, ម៉ូតូ Keewey ដែលបានប្រើ, ម៉ូតូ Keewey មួយ\u200bទឹក, ម៉ូតូ Keewey សម្រាប់លក់, ម៉ូតូ Keewey តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ Keewey, ម៉ូតូ Keewey ទាំងអស់" name="keywords"/>\n   <meta conte
# ...

# %%
html9="https://www.khmer24.com/km/motorcycles/keewey.html"


with open('KeeweyMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,190):
    x = 45*i
    html9="https://www.khmer24.com/km/motorcycles/keewey.html"
    
    
    with open('KEEWEY.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 165): 
   
    
    Data9 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data9:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
KEEYWEY =pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
KEEYWEY
# Out:
#                                                   Title  \
# 0                                               លក់ ចោល
# 1                                                Keeway
# 2                                   Keeway​ ប្រញ៉ាប់លុយ
# 3                                ម៉ូតូKee way black 017
# 4                                 Keeway RKV 150 custom
# ...                                                 ...
# 2800  ម៉ូឌែលថ្មីចេស Keeway VIESTE 175cc year 2023 ថែ...
# 2801                  Occasion.  Selling due to return.
# 2802                               BASICALLY BRAND NEW!
# 2803                                            លក់មូតូ
# 2804          ខ្ញុំបាទចង់លក់ប្រញាប់លុយមានពន្ធត្រឹមត្រូវ
#
#                                             Description      Price Location  \
# 0                                            0966902493       $150  ភ្នំពេញ
# 1                                          Good machine       $380  ភ្នំពេញ
# ...

# %% [markdown]
# ### 11.BMW

# %%
html10="https://www.khmer24.com/km/motorcycles/bmw.html"
request10 = Request(html10, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage10 = urlopen(request10).read()

soup = BeautifulSoup(webpage10, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ BMW ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ BMW, ម៉ូតូ BMW សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ BMW ថ្មី, ម៉ូតូ BMW ដែលបានប្រើ, ម៉ូតូ BMW មួយ\u200bទឹក, ម៉ូតូ BMW សម្រាប់លក់, ម៉ូតូ BMW តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ BMW, ម៉ូតូ BMW ទាំងអស់" name="keywords"/>\n   <meta content="ទិញ ឬលក់ ម៉ូតូ BMW ថ្មី ម៉
# ...

# %%
html10="https://www.khmer24.com/km/motorcycles/bmw.html"


with open('BMWMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,190):
    x = 45*i
    html10="https://www.khmer24.com/km/motorcycles/bmw.html"
    
    
    with open('bmw.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 165): 
   
    
    Data10 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data10:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
BMW =pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
BMW
# Out:
#                                 Title  \
# 0          BMW C400GT 2019 from Japan
# 1      BMW C600 Sport 2015 from Japan
# 2              BMW GSA1200 ឆ្នាំ 2016
# 3        BMW GSA1250 40th anniversary
# 4                 BMW GSA 1200 & 1250
# ...                               ...
# 8245                    BMW s1000rr 💙
# 8246  BMW C400x 019 ជប៉ុន ១ទឹកខ្ចី99%
# 8247                          R1150GS
# 8248             BMW GS R1250 HP 2020
# 8249                BMW GS R1200 2018
#
#                                             Description    Price  \
# 0     ✈︎ #81A, St. 608 ពីស្តុបត្រឡោកបែក ទៅស្តុបរង្វង...   $6,800
# 1     ➜➜➜ចូលមើលម៉ូដែលផ្សេងទៀត https://t.me/imotokh \...   $4,850
# 2     ម៉ូតូស្អាតខ្លាំងណាស់ មិនដែលប៉ះរឺដួល គីឡូតិច 2ម...  $11,800
# 3     🔔BMW GSA 1250 40 anniversary🔔\n👉 ឆ្នាំ2022 ទើប...   $3,200
# 4     ហាងលក់ម៉ូតូធំ​ BMW GSA ICE23\nចង់បានម៉ូតូល្អកុ...  $15,500
# ...                                                 ...      ...
# ...

# %% [markdown]
# ### 12.HARLEY

# %%
html11="https://www.khmer24.com/km/motorcycles/harley-davidson.html"


request11 = Request(html11, headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'})
webpage11 = urlopen(request11).read()

soup = BeautifulSoup(webpage10, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="km">\n <head>\n  <meta content="Vj3nFdA-uZGZFOP3ZajI-jYDUUPyNZL-EMAE5WbY94A" name="google-site-verification"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="#028dcf" name="theme-color">\n   <meta content="width=device-width" name="viewport"/>\n   <link href="https://www.khmer24.com/favicon.ico" rel="shortcut icon"/>\n   <!-- <link href="https://fonts.googleapis.com/css?family=Hanuman" rel="stylesheet"> -->\n   <!--[if lt IE 9]>\r\n\t\t  <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>\r\n\t\t<![endif]-->\n   <title>\n    ម៉ូតូ BMW ថ្មី និងមួយទឹកសម្រាប់លក់ ក្នុង កម្ពុជា - Khmer24.com\n   </title>\n   <meta content="ម៉ូតូ BMW, ម៉ូតូ BMW សម្រាប់លក់នៅក្នុង កម្ពុជា, ម៉ូតូ BMW ថ្មី, ម៉ូតូ BMW ដែលបានប្រើ, ម៉ូតូ BMW មួយ\u200bទឹក, ម៉ូតូ BMW សម្រាប់លក់, ម៉ូតូ BMW តម្លៃថោក,\u200b តម្លៃ ម៉ូតូ BMW, ម៉ូតូ BMW ទាំងអស់" name="keywords"/>\n   <meta content="ទិញ ឬលក់ ម៉ូតូ BMW ថ្មី ម៉
# ...

# %%
html11="https://www.khmer24.com/km/motorcycles/harley-davidson.html"


with open('HARLEYMOTOR.csv','a',encoding = 'utf-7', newline = '') as f:
        
        thewriter = writer(f)
        header = ['Title','Description','Price','Location','Time']
        thewriter.writerow(header)
        
        for i in soup.findAll('div', class_ = 'item-detail') :
            
            title = i.find('h2', class_="item-title").text
            description = i.find('p', class_='description').text
            price = i.find('span', class_="price").text
            location = i.find('li').text
            time = i.find('time').text
            
            info = [title, description, price, location, time]

# Select to other page

for i in range(1,190):
    x = 45*i
    html11="https://www.khmer24.com/km/motorcycles/harley-davidson.html"
    
    
    with open('HARLEY.csv','a',encoding = 'utf-7', newline = '') as f:
            thewriter = writer(f)
            
            for i in soup.findAll('div', class_ = 'item-detail') :
                title = i.find('h2', class_="item-title").text
                description = i.find('p', class_='description').text
                price = i.find('span', class_="price").text
                location = i.find('li').text
                time = i.find('time').text
                
                info = [title, description, price, location, time]
                
                thewriter.writerow(info)

# %%
title = []
description = []
price = []
location = []
time = []

# %%
for i in range(0, 165): 
   
    
    Data11 = soup.findAll("div", {"class" : "item-detail"})
    
    for item in Data11:

        try:
    
            title.append(item.find("h2", {"class":"item-title"}).get_text().strip('\n'))

        except:
            title.append('n/a')

        try:
            description.append(item.find("p", {"class":"description"}).get_text().strip('\n'))

        except: 
            description.append('n/a') 

        try:
            price.append(item.find("span", {"class":"price"}).get_text())

        except:
            price.append('n/a')

        try:
            location.append(item.find("li").get_text())

        except:
            location.append('n/a')  

        try:
            time.append(item.find("time").get_text())

        except:
            time.append('n/a')

# %%
HARLEY =pd.DataFrame({'Title': title ,
                           'Description': description,
                           'Price': price,
                           'Location': location,
                           'Time' : time,
                          })
HARLEY
# Out:
#                                 Title  \
# 0          BMW C400GT 2019 from Japan
# 1      BMW C600 Sport 2015 from Japan
# 2              BMW GSA1200 ឆ្នាំ 2016
# 3        BMW GSA1250 40th anniversary
# 4                 BMW GSA 1200 & 1250
# ...                               ...
# 8245                    BMW s1000rr 💙
# 8246  BMW C400x 019 ជប៉ុន ១ទឹកខ្ចី99%
# 8247                          R1150GS
# 8248             BMW GS R1250 HP 2020
# 8249                BMW GS R1200 2018
#
#                                             Description    Price  \
# 0     ✈︎ #81A, St. 608 ពីស្តុបត្រឡោកបែក ទៅស្តុបរង្វង...   $6,800
# 1     ➜➜➜ចូលមើលម៉ូដែលផ្សេងទៀត https://t.me/imotokh \...   $4,850
# 2     ម៉ូតូស្អាតខ្លាំងណាស់ មិនដែលប៉ះរឺដួល គីឡូតិច 2ម...  $11,800
# 3     🔔BMW GSA 1250 40 anniversary🔔\n👉 ឆ្នាំ2022 ទើប...   $3,200
# 4     ហាងលក់ម៉ូតូធំ​ BMW GSA ICE23\nចង់បានម៉ូតូល្អកុ...  $15,500
# ...                                                 ...      ...
# ...
